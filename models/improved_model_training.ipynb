# %% [markdown]
# # Dataset & Description
# ![image.png](attachment:407f4e35-9509-43c8-9d5b-68532db6714d.png)
#
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.

# %% [markdown]
# # Functions for Deep Learning Process

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import DenseNet169

from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation
from tensorflow.keras.models import Model, Sequential
from keras.applications.nasnet import NASNetLarge
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

from tensorflow.keras import optimizers
from collections import Counter
import matplotlib.pyplot as plt

from tensorflow.keras.utils import plot_model
from IPython.display import Image

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D

# %%
METRICS = [
    tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc', multi_label=True),
    tf.keras.metrics.AUC(name='prc', curve='PR', multi_label=True)
]

# %%
def Train_Val_Plot2(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,recall,val_recall,prc,val_prc):
    
    fig, (ax1, ax2,ax3,ax4,ax5,ax6) = plt.subplots(1,6, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(recall) + 1), recall)
    ax5.plot(range(1, len(val_recall) + 1), val_auc)
    ax5.set_title('History of recall')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('recall')
    ax5.legend(['training', 'validation'])
    
    ax6.plot(range(1, len(prc) + 1), prc)
    ax6.plot(range(1, len(val_prc) + 1), val_prc)
    ax6.set_title('History of prc')
    ax6.set_xlabel('Epochs')
    ax6.set_ylabel('prc')
    ax6.legend(['training', 'validation'])
    
    recall,val_recall,prc,val_prc
    
#     ax5.plot(range(1, len(f1) + 1), f1)
#     ax5.plot(range(1, len(val_f1) + 1), val_f1)
#     ax5.set_title('History of F1-score')
#     ax5.set_xlabel('Epochs')
#     ax5.set_ylabel('F1 score')
#     ax5.legend(['training', 'validation'])


    plt.show()

# %%
def initDataGens():
    
    train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,
                                   rotation_range=0.3, #5,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   #zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=False,
                                   fill_mode='nearest')

#     valid_datagen = ImageDataGenerator(rescale = 1./255,
#                                   validation_split = 0.2
#                                   )

    test_datagen  = ImageDataGenerator(rescale = 1./255)


    return train_datagen, test_datagen, test_datagen

# %%
def initDataSets(train, test, train_datagen, valid_datagen, test_datagen, classes_):
    
    train_dataset  = train_datagen.flow_from_directory(directory = train,#'../input/fer2013/train',
                                                   target_size = (48,48),
                                                   class_mode = 'categorical',
                                                   classes=classes_,
                                                   subset = 'training',
                                                   batch_size = 64)

    valid_dataset = train_datagen.flow_from_directory(directory = train,#'../input/fer2013/train',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  classes=classes_,
                                                  subset = 'validation',
                                                  batch_size = 64)
    
#     valid_dataset = valid_datagen.flow_from_directory(directory = train,#'../input/fer2013/train',
#                                                   target_size = (48,48),
#                                                   class_mode = 'categorical',
#                                                   classes=classes_,
#                                                   subset = 'validation',
#                                                   batch_size = 64)

    test_dataset = test_datagen.flow_from_directory(directory = test, #'../input/fer2013/test',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  classes=classes_,
                                                  batch_size = 64)


    return train_dataset, valid_dataset, test_dataset

# %%
def updateBaseModel(base_model, num_classes):
    
    for layer in base_model.layers[:]:
        layer.trainable=True
    
    # Building Model
    model=Sequential()
    model.add(base_model)
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(BatchNormalization())
    model.add(Dense(32,kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(32,kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(32,kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
def plot_DG(data_generator):
    counter = Counter(data_generator.classes)
    data_items = counter.items() # dict_items([(0, 1648), (1, 3614)])
    l = list(counter.items())
    print(l)
#     pd.DataFrame(l, columns=['class','count']).set_index('class').plot(kind='bar', colormap='Set2');
    
    plt.bar(range(len(l)), [val[1] for val in l], align='center')
    plt.xticks(range(len(l)), [val[0] for val in l])
    plt.xticks(rotation=70)
    plt.show()
    
#     df = pd.DataFrame(l, columns=['index', 'observers'])
#     print(df)
# ['Anger', 'Disgust', 'Fear', 'Happy','Neutral','Sad', 'Surprise']

# %%
def getClassWeights(train_dataset):
    
    counter = Counter(train_dataset.classes)                          
    max_val = float(max(counter.values()))       
    class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}    
    print(class_weights)

    return class_weights

# %%
def plotModel(model):
    
    plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
    Image(filename='convnet.png')

# %%
def getAllForTraining(model, save_h5_to_path, epochs_):
    
    lrd = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=7,
        min_lr=1e-7,
        verbose=1,
    )

    mcp_5categories = ModelCheckpoint(save_h5_to_path)

    # es = EarlyStopping(verbose=1, patience=20)
    es = EarlyStopping(
        monitor='val_accuracy',
        min_delta=0.00005,
        patience=11,
        verbose=1,
        restore_best_weights=True,
    )

    # optimizers.Adam(learning_rate=1e-3, decay=1e-3 / epochs)
    # model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=METRICS)
    t_epochs = epochs_

    optim = optimizers.Adam(learning_rate=1e-3, decay=1e-3 / t_epochs)
    model.compile(optimizer=optim, loss='categorical_crossentropy',metrics=METRICS)
    model.summary()

    return lrd, mcp_5categories, es, t_epochs, model, t_epochs

# %%
def plotConfusionMatrix(model, test_dataset, num_of_test_samples, batch_size, target_names):
    
    #Confution Matrix and Classification Report
    Y_pred = model.predict(test_dataset, num_of_test_samples // batch_size+1)
    y_pred = np.argmax(Y_pred, axis=1)
    print('Confusion Matrix')
    cm = confusion_matrix(test_dataset.classes, y_pred)
    print('Classification Report')
    print(classification_report(test_dataset.classes, y_pred, target_names=target_names))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()

# %% [markdown]
# # Init for Deep Learning

# %%
# 7 emotions

target_names = ['Anger','Disgust','Fear','Happy','Neutral','Sad','Surprise']
num_classes = len(target_names)
train_path = '../input/fer2013pluscleanedaugmballanced1/train'
test_path = '../input/fer2013pluscleanedaugmballanced1/test'
save_model_h5_to_path = 'MobileNet-Classification-7emotions-CNN.h5'
epochs = 100

train_datagen, valid_datagen, test_datagen = initDataGens()
train_dataset, valid_dataset, test_dataset = initDataSets(train_path, test_path, train_datagen, valid_datagen, test_datagen, target_names)
class_weights = getClassWeights(train_dataset)
plot_DG(train_dataset)

# base_model = tf.keras.applications.ResNet50(input_shape=(48,48,3),include_top=False,weights="imagenet")
base_model = tf.keras.applications.MobileNet(input_shape=(48,48,3),include_top=False,weights="imagenet")

# model = build_net(optimizers.SGD(learning_rate=0.01, momentum=0.9), 7, METRICS)

model = updateBaseModel(base_model, len(target_names))
lrd, mcp_5categories, es, t_epochs, model, t_epochs = getAllForTraining(model, save_model_h5_to_path, epochs)
# Out:
# Found 18603 images belonging to 7 classes.
# Found 4648 images belonging to 7 classes.
# Found 5772 images belonging to 7 classes.
# {0: 1.0184766214177978, 1: 1.0025983667409057, 2: 1.0089652596189764, 3: 1.012368815592204, 4: 1.0, 5: 1.057556773688332, 6: 1.0165600301091458}
# [(0, 2652), (1, 2694), (2, 2677), (3, 2668), (4, 2701), (5, 2554), (6, 2657)]
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 1, 1, 1024)        3228864
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense (Dense)                (None, 32)                32800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 3,268,487
# Trainable params: 3,244,359
# Non-trainable params: 24,128
# _________________________________________________________________

# %% [markdown]
# # Deep Learning

# %%
history1 = model.fit(train_dataset,validation_data=valid_dataset,epochs = t_epochs,verbose = 1,callbacks=[lrd,mcp_5categories,es], class_weight=class_weights)
# Out:
# Epoch 1/100
# 291/291 [==============================] - 43s 148ms/step - loss: 1.5234 - accuracy: 0.4039 - precision: 0.7193 - recall: 0.1643 - auc: 0.7823 - prc: 0.4053 - val_loss: 1.1987 - val_accuracy: 0.5499 - val_precision: 0.7695 - val_recall: 0.3505 - val_auc: 0.8658 - val_prc: 0.5757
# Epoch 2/100
# 291/291 [==============================] - 42s 144ms/step - loss: 1.3904 - accuracy: 0.4799 - precision: 0.7578 - recall: 0.2412 - auc: 0.8238 - prc: 0.4819 - val_loss: 1.0616 - val_accuracy: 0.6000 - val_precision: 0.8253 - val_recall: 0.3944 - val_auc: 0.8974 - val_prc: 0.6524
# Epoch 3/100
# 291/291 [==============================] - 42s 143ms/step - loss: 1.2908 - accuracy: 0.5346 - precision: 0.7912 - recall: 0.2916 - auc: 0.8492 - prc: 0.5377 - val_loss: 1.0678 - val_accuracy: 0.5927 - val_precision: 0.7495 - val_recall: 0.4288 - val_auc: 0.9007 - val_prc: 0.6653
# Epoch 4/100
# 291/291 [==============================] - 42s 143ms/step - loss: 1.2412 - accuracy: 0.5577 - precision: 0.8078 - recall: 0.3174 - auc: 0.8616 - prc: 0.5649 - val_loss: 0.9310 - val_accuracy: 0.6631 - val_precision: 0.8591 - val_recall: 0.4251 - val_auc: 0.9206 - val_prc: 0.7105
# Epoch 5/100
# 291/291 [==============================] - 41s 141ms/step - loss: 1.1883 - accuracy: 0.5770 - precision: 0.8098 - recall: 0.3405 - auc: 0.8733 - prc: 0.5904 - val_loss: 1.1481 - val_accuracy: 0.5957 - val_precision: 0.7679 - val_recall: 0.3793 - val_auc: 0.8861 - val_prc: 0.6516
# Epoch 6/100
# 291/291 [==============================] - 41s 141ms/step - loss: 1.1541 - accuracy: 0.5942 - precision: 0.8142 - recall: 0.3697 - auc: 0.8799 - prc: 0.6107 - val_loss: 1.1241 - val_accuracy: 0.5863 - val_precision: 0.8591 - val_recall: 0.3660 - val_auc: 0.8972 - val_prc: 0.6708
# Epoch 7/100
# 291/291 [==============================] - 42s 144ms/step - loss: 1.1352 - accuracy: 0.6055 - precision: 0.8199 - recall: 0.3844 - auc: 0.8849 - prc: 0.6242 - val_loss: 0.8822 - val_accuracy: 0.6803 - val_precision: 0.8501 - val_recall: 0.5039 - val_auc: 0.9272 - val_prc: 0.7393
# Epoch 8/100
# 291/291 [==============================] - 41s 142ms/step - loss: 1.1038 - accuracy: 0.6155 - precision: 0.8189 - recall: 0.4017 - auc: 0.8902 - prc: 0.6349 - val_loss: 0.8972 - val_accuracy: 0.6889 - val_precision: 0.8631 - val_recall: 0.4841 - val_auc: 0.9284 - val_prc: 0.7467
# Epoch 9/100
# 291/291 [==============================] - 41s 140ms/step - loss: 1.0752 - accuracy: 0.6380 - precision: 0.8151 - recall: 0.4271 - auc: 0.8973 - prc: 0.6546 - val_loss: 0.8432 - val_accuracy: 0.7068 - val_precision: 0.8444 - val_recall: 0.5243 - val_auc: 0.9360 - val_prc: 0.7623
# Epoch 10/100
# 291/291 [==============================] - 41s 142ms/step - loss: 1.0620 - accuracy: 0.6396 - precision: 0.8064 - recall: 0.4360 - auc: 0.9001 - prc: 0.6610 - val_loss: 0.8686 - val_accuracy: 0.6921 - val_precision: 0.8178 - val_recall: 0.5686 - val_auc: 0.9320 - val_prc: 0.7613
# Epoch 11/100
# 291/291 [==============================] - 41s 142ms/step - loss: 1.0398 - accuracy: 0.6505 - precision: 0.8103 - recall: 0.4570 - auc: 0.9031 - prc: 0.6727 - val_loss: 0.8805 - val_accuracy: 0.6878 - val_precision: 0.8008 - val_recall: 0.5327 - val_auc: 0.9353 - val_prc: 0.7565
# Epoch 12/100
# 291/291 [==============================] - 41s 141ms/step - loss: 1.0289 - accuracy: 0.6539 - precision: 0.8003 - recall: 0.4679 - auc: 0.9053 - prc: 0.6734 - val_loss: 0.9463 - val_accuracy: 0.6786 - val_precision: 0.7668 - val_recall: 0.5525 - val_auc: 0.9242 - val_prc: 0.7383
# Epoch 13/100
# 291/291 [==============================] - 41s 141ms/step - loss: 1.0073 - accuracy: 0.6634 - precision: 0.7998 - recall: 0.4897 - auc: 0.9094 - prc: 0.6893 - val_loss: 0.7856 - val_accuracy: 0.7390 - val_precision: 0.8209 - val_recall: 0.6459 - val_auc: 0.9432 - val_prc: 0.7905
# Epoch 14/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.9929 - accuracy: 0.6689 - precision: 0.7980 - recall: 0.5038 - auc: 0.9114 - prc: 0.6911 - val_loss: 0.9026 - val_accuracy: 0.6861 - val_precision: 0.7739 - val_recall: 0.6031 - val_auc: 0.9273 - val_prc: 0.7588
# Epoch 15/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.9836 - accuracy: 0.6737 - precision: 0.8037 - recall: 0.5131 - auc: 0.9130 - prc: 0.6980 - val_loss: 0.8611 - val_accuracy: 0.7091 - val_precision: 0.8007 - val_recall: 0.6291 - val_auc: 0.9327 - val_prc: 0.7655
# Epoch 16/100
# 291/291 [==============================] - 41s 139ms/step - loss: 0.9582 - accuracy: 0.6831 - precision: 0.8084 - recall: 0.5370 - auc: 0.9171 - prc: 0.7093 - val_loss: 0.7499 - val_accuracy: 0.7453 - val_precision: 0.8177 - val_recall: 0.6631 - val_auc: 0.9491 - val_prc: 0.8074
# Epoch 17/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.9404 - accuracy: 0.6899 - precision: 0.8016 - recall: 0.5515 - auc: 0.9206 - prc: 0.7155 - val_loss: 0.7900 - val_accuracy: 0.7330 - val_precision: 0.8014 - val_recall: 0.6599 - val_auc: 0.9434 - val_prc: 0.8007
# Epoch 18/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.9501 - accuracy: 0.6882 - precision: 0.7903 - recall: 0.5579 - auc: 0.9189 - prc: 0.7158 - val_loss: 0.7269 - val_accuracy: 0.7575 - val_precision: 0.8278 - val_recall: 0.6898 - val_auc: 0.9513 - val_prc: 0.8156
# Epoch 19/100
# 291/291 [==============================] - 41s 139ms/step - loss: 0.9359 - accuracy: 0.6907 - precision: 0.7993 - recall: 0.5646 - auc: 0.9211 - prc: 0.7230 - val_loss: 0.7454 - val_accuracy: 0.7571 - val_precision: 0.8110 - val_recall: 0.6848 - val_auc: 0.9492 - val_prc: 0.8092
# Epoch 20/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.9230 - accuracy: 0.6944 - precision: 0.8025 - recall: 0.5695 - auc: 0.9221 - prc: 0.7249 - val_loss: 0.7129 - val_accuracy: 0.7601 - val_precision: 0.8180 - val_recall: 0.6973 - val_auc: 0.9556 - val_prc: 0.8312
# Epoch 21/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.8944 - accuracy: 0.7070 - precision: 0.8029 - recall: 0.5913 - auc: 0.9272 - prc: 0.7383 - val_loss: 0.8170 - val_accuracy: 0.7233 - val_precision: 0.7913 - val_recall: 0.6674 - val_auc: 0.9406 - val_prc: 0.8021
# Epoch 22/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.8859 - accuracy: 0.7118 - precision: 0.8075 - recall: 0.5993 - auc: 0.9280 - prc: 0.7444 - val_loss: 0.7891 - val_accuracy: 0.7407 - val_precision: 0.7996 - val_recall: 0.6824 - val_auc: 0.9441 - val_prc: 0.8110
# Epoch 23/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.8830 - accuracy: 0.7134 - precision: 0.8071 - recall: 0.6037 - auc: 0.9289 - prc: 0.7467 - val_loss: 0.8413 - val_accuracy: 0.7068 - val_precision: 0.7799 - val_recall: 0.6487 - val_auc: 0.9391 - val_prc: 0.7880
# Epoch 24/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.8733 - accuracy: 0.7142 - precision: 0.8104 - recall: 0.6053 - auc: 0.9297 - prc: 0.7516 - val_loss: 0.7095 - val_accuracy: 0.7620 - val_precision: 0.8206 - val_recall: 0.7018 - val_auc: 0.9556 - val_prc: 0.8292
# Epoch 25/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.8657 - accuracy: 0.7240 - precision: 0.8136 - recall: 0.6174 - auc: 0.9311 - prc: 0.7522 - val_loss: 0.6838 - val_accuracy: 0.7631 - val_precision: 0.8156 - val_recall: 0.7128 - val_auc: 0.9576 - val_prc: 0.8329
# Epoch 26/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.8580 - accuracy: 0.7233 - precision: 0.8131 - recall: 0.6162 - auc: 0.9321 - prc: 0.7567 - val_loss: 0.6932 - val_accuracy: 0.7644 - val_precision: 0.8301 - val_recall: 0.7020 - val_auc: 0.9554 - val_prc: 0.8301
# Epoch 27/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.8527 - accuracy: 0.7221 - precision: 0.8121 - recall: 0.6232 - auc: 0.9332 - prc: 0.7622 - val_loss: 0.8572 - val_accuracy: 0.7048 - val_precision: 0.7860 - val_recall: 0.6338 - val_auc: 0.9417 - val_prc: 0.7993
# Epoch 28/100
# 291/291 [==============================] - 41s 139ms/step - loss: 0.8466 - accuracy: 0.7283 - precision: 0.8150 - recall: 0.6260 - auc: 0.9337 - prc: 0.7633 - val_loss: 0.6962 - val_accuracy: 0.7747 - val_precision: 0.8348 - val_recall: 0.7210 - val_auc: 0.9542 - val_prc: 0.8327
# Epoch 29/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.8145 - accuracy: 0.7406 - precision: 0.8213 - recall: 0.6506 - auc: 0.9382 - prc: 0.7766 - val_loss: 0.6648 - val_accuracy: 0.7771 - val_precision: 0.8153 - val_recall: 0.7324 - val_auc: 0.9584 - val_prc: 0.8422
# Epoch 30/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.8194 - accuracy: 0.7394 - precision: 0.8184 - recall: 0.6456 - auc: 0.9374 - prc: 0.7723 - val_loss: 0.6413 - val_accuracy: 0.7851 - val_precision: 0.8275 - val_recall: 0.7388 - val_auc: 0.9621 - val_prc: 0.8542
# Epoch 31/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.8071 - accuracy: 0.7423 - precision: 0.8221 - recall: 0.6548 - auc: 0.9391 - prc: 0.7761 - val_loss: 0.6494 - val_accuracy: 0.7877 - val_precision: 0.8367 - val_recall: 0.7476 - val_auc: 0.9586 - val_prc: 0.8521
# Epoch 32/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.7941 - accuracy: 0.7444 - precision: 0.8228 - recall: 0.6564 - auc: 0.9409 - prc: 0.7830 - val_loss: 0.7616 - val_accuracy: 0.7442 - val_precision: 0.8150 - val_recall: 0.6786 - val_auc: 0.9486 - val_prc: 0.8303
# Epoch 33/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.7841 - accuracy: 0.7518 - precision: 0.8194 - recall: 0.6678 - auc: 0.9419 - prc: 0.7855 - val_loss: 0.7066 - val_accuracy: 0.7549 - val_precision: 0.8177 - val_recall: 0.6986 - val_auc: 0.9550 - val_prc: 0.8274
# Epoch 34/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.7882 - accuracy: 0.7457 - precision: 0.8241 - recall: 0.6620 - auc: 0.9420 - prc: 0.7867 - val_loss: 0.6185 - val_accuracy: 0.7915 - val_precision: 0.8405 - val_recall: 0.7380 - val_auc: 0.9628 - val_prc: 0.8550
# Epoch 35/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.7720 - accuracy: 0.7510 - precision: 0.8249 - recall: 0.6727 - auc: 0.9441 - prc: 0.7913 - val_loss: 0.8062 - val_accuracy: 0.7141 - val_precision: 0.7618 - val_recall: 0.6646 - val_auc: 0.9521 - val_prc: 0.8090
# Epoch 36/100
# 291/291 [==============================] - 43s 147ms/step - loss: 0.7666 - accuracy: 0.7514 - precision: 0.8262 - recall: 0.6733 - auc: 0.9455 - prc: 0.7969 - val_loss: 0.7064 - val_accuracy: 0.7713 - val_precision: 0.8269 - val_recall: 0.7194 - val_auc: 0.9560 - val_prc: 0.8469
# Epoch 37/100
# 291/291 [==============================] - 43s 148ms/step - loss: 0.7498 - accuracy: 0.7625 - precision: 0.8286 - recall: 0.6845 - auc: 0.9465 - prc: 0.7994 - val_loss: 0.6609 - val_accuracy: 0.7790 - val_precision: 0.8177 - val_recall: 0.7429 - val_auc: 0.9612 - val_prc: 0.8457
# Epoch 38/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.7464 - accuracy: 0.7623 - precision: 0.8302 - recall: 0.6880 - auc: 0.9471 - prc: 0.8040 - val_loss: 0.6894 - val_accuracy: 0.7765 - val_precision: 0.8405 - val_recall: 0.7268 - val_auc: 0.9556 - val_prc: 0.8441
# Epoch 39/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.7341 - accuracy: 0.7658 - precision: 0.8298 - recall: 0.6942 - auc: 0.9489 - prc: 0.8108 - val_loss: 0.6455 - val_accuracy: 0.7765 - val_precision: 0.8219 - val_recall: 0.7309 - val_auc: 0.9591 - val_prc: 0.8460
# Epoch 40/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.7342 - accuracy: 0.7676 - precision: 0.8315 - recall: 0.6968 - auc: 0.9487 - prc: 0.8054 - val_loss: 0.6346 - val_accuracy: 0.7883 - val_precision: 0.8560 - val_recall: 0.7253 - val_auc: 0.9625 - val_prc: 0.8551
# Epoch 41/100
# 291/291 [==============================] - 40s 136ms/step - loss: 0.7163 - accuracy: 0.7753 - precision: 0.8401 - recall: 0.7050 - auc: 0.9507 - prc: 0.8164 - val_loss: 0.6234 - val_accuracy: 0.7922 - val_precision: 0.8425 - val_recall: 0.7504 - val_auc: 0.9623 - val_prc: 0.8585
# Epoch 42/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.7218 - accuracy: 0.7678 - precision: 0.8367 - recall: 0.6957 - auc: 0.9498 - prc: 0.8089 - val_loss: 0.6853 - val_accuracy: 0.7713 - val_precision: 0.8155 - val_recall: 0.7358 - val_auc: 0.9557 - val_prc: 0.8446
# Epoch 43/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.7096 - accuracy: 0.7739 - precision: 0.8382 - recall: 0.7042 - auc: 0.9516 - prc: 0.8171 - val_loss: 0.6523 - val_accuracy: 0.7855 - val_precision: 0.8316 - val_recall: 0.7500 - val_auc: 0.9576 - val_prc: 0.8469
# Epoch 44/100
# 291/291 [==============================] - 42s 143ms/step - loss: 0.7044 - accuracy: 0.7770 - precision: 0.8374 - recall: 0.7081 - auc: 0.9522 - prc: 0.8182 - val_loss: 0.6001 - val_accuracy: 0.8008 - val_precision: 0.8352 - val_recall: 0.7657 - val_auc: 0.9648 - val_prc: 0.8616
# Epoch 45/100
# 291/291 [==============================] - 42s 144ms/step - loss: 0.7015 - accuracy: 0.7767 - precision: 0.8386 - recall: 0.7140 - auc: 0.9529 - prc: 0.8205 - val_loss: 0.6193 - val_accuracy: 0.7971 - val_precision: 0.8537 - val_recall: 0.7558 - val_auc: 0.9626 - val_prc: 0.8567
# Epoch 46/100
# 291/291 [==============================] - 42s 143ms/step - loss: 0.7016 - accuracy: 0.7806 - precision: 0.8421 - recall: 0.7181 - auc: 0.9525 - prc: 0.8197 - val_loss: 0.6278 - val_accuracy: 0.7948 - val_precision: 0.8354 - val_recall: 0.7569 - val_auc: 0.9608 - val_prc: 0.8545
# Epoch 47/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.6740 - accuracy: 0.7880 - precision: 0.8442 - recall: 0.7299 - auc: 0.9558 - prc: 0.8332 - val_loss: 0.5941 - val_accuracy: 0.8062 - val_precision: 0.8432 - val_recall: 0.7717 - val_auc: 0.9633 - val_prc: 0.8658
# Epoch 48/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.6783 - accuracy: 0.7873 - precision: 0.8396 - recall: 0.7291 - auc: 0.9555 - prc: 0.8279 - val_loss: 0.6699 - val_accuracy: 0.7823 - val_precision: 0.8249 - val_recall: 0.7468 - val_auc: 0.9600 - val_prc: 0.8558
# Epoch 49/100
# 291/291 [==============================] - 41s 142ms/step - loss: 0.6579 - accuracy: 0.7961 - precision: 0.8484 - recall: 0.7374 - auc: 0.9576 - prc: 0.8383 - val_loss: 0.6328 - val_accuracy: 0.7879 - val_precision: 0.8267 - val_recall: 0.7593 - val_auc: 0.9599 - val_prc: 0.8561
# Epoch 50/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.6694 - accuracy: 0.7904 - precision: 0.8463 - recall: 0.7341 - auc: 0.9561 - prc: 0.8326 - val_loss: 0.5819 - val_accuracy: 0.8081 - val_precision: 0.8491 - val_recall: 0.7612 - val_auc: 0.9653 - val_prc: 0.8690
# Epoch 51/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.6740 - accuracy: 0.7863 - precision: 0.8433 - recall: 0.7269 - auc: 0.9557 - prc: 0.8334 - val_loss: 0.5941 - val_accuracy: 0.8105 - val_precision: 0.8447 - val_recall: 0.7724 - val_auc: 0.9638 - val_prc: 0.8658
# Epoch 52/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.6573 - accuracy: 0.7909 - precision: 0.8465 - recall: 0.7362 - auc: 0.9575 - prc: 0.8365 - val_loss: 0.6031 - val_accuracy: 0.7975 - val_precision: 0.8450 - val_recall: 0.7509 - val_auc: 0.9628 - val_prc: 0.8643
# Epoch 53/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.6427 - accuracy: 0.7985 - precision: 0.8503 - recall: 0.7428 - auc: 0.9593 - prc: 0.8424 - val_loss: 0.6009 - val_accuracy: 0.7963 - val_precision: 0.8377 - val_recall: 0.7573 - val_auc: 0.9627 - val_prc: 0.8611
# Epoch 54/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.6390 - accuracy: 0.8001 - precision: 0.8515 - recall: 0.7490 - auc: 0.9590 - prc: 0.8427 - val_loss: 0.6683 - val_accuracy: 0.7797 - val_precision: 0.8322 - val_recall: 0.7319 - val_auc: 0.9581 - val_prc: 0.8572
# Epoch 55/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.6284 - accuracy: 0.8047 - precision: 0.8537 - recall: 0.7535 - auc: 0.9601 - prc: 0.8475 - val_loss: 0.6168 - val_accuracy: 0.7967 - val_precision: 0.8431 - val_recall: 0.7629 - val_auc: 0.9634 - val_prc: 0.8691
# Epoch 56/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.6267 - accuracy: 0.8034 - precision: 0.8553 - recall: 0.7505 - auc: 0.9608 - prc: 0.8468 - val_loss: 0.6412 - val_accuracy: 0.7935 - val_precision: 0.8294 - val_recall: 0.7571 - val_auc: 0.9584 - val_prc: 0.8533
# Epoch 57/100
# 291/291 [==============================] - 39s 135ms/step - loss: 0.6205 - accuracy: 0.8055 - precision: 0.8539 - recall: 0.7560 - auc: 0.9614 - prc: 0.8496 - val_loss: 0.6167 - val_accuracy: 0.8019 - val_precision: 0.8359 - val_recall: 0.7750 - val_auc: 0.9630 - val_prc: 0.8631
# Epoch 58/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.6169 - accuracy: 0.8095 - precision: 0.8558 - recall: 0.7623 - auc: 0.9618 - prc: 0.8522 - val_loss: 0.5848 - val_accuracy: 0.7993 - val_precision: 0.8448 - val_recall: 0.7646 - val_auc: 0.9668 - val_prc: 0.8704
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 59/100
# 291/291 [==============================] - 39s 136ms/step - loss: 0.5706 - accuracy: 0.8205 - precision: 0.8664 - recall: 0.7761 - auc: 0.9666 - prc: 0.8676 - val_loss: 0.5799 - val_accuracy: 0.8102 - val_precision: 0.8493 - val_recall: 0.7833 - val_auc: 0.9668 - val_prc: 0.8775
# Epoch 60/100
# 291/291 [==============================] - 41s 139ms/step - loss: 0.5657 - accuracy: 0.8255 - precision: 0.8693 - recall: 0.7818 - auc: 0.9672 - prc: 0.8667 - val_loss: 0.5471 - val_accuracy: 0.8221 - val_precision: 0.8552 - val_recall: 0.7930 - val_auc: 0.9697 - val_prc: 0.8851
# Epoch 61/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.5461 - accuracy: 0.8302 - precision: 0.8699 - recall: 0.7893 - auc: 0.9693 - prc: 0.8763 - val_loss: 0.5717 - val_accuracy: 0.8115 - val_precision: 0.8443 - val_recall: 0.7861 - val_auc: 0.9676 - val_prc: 0.8776
# Epoch 62/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.5396 - accuracy: 0.8356 - precision: 0.8730 - recall: 0.7932 - auc: 0.9693 - prc: 0.8753 - val_loss: 0.5710 - val_accuracy: 0.8186 - val_precision: 0.8510 - val_recall: 0.7898 - val_auc: 0.9661 - val_prc: 0.8766
# Epoch 63/100
# 291/291 [==============================] - 40s 136ms/step - loss: 0.5341 - accuracy: 0.8358 - precision: 0.8713 - recall: 0.7987 - auc: 0.9701 - prc: 0.8769 - val_loss: 0.5366 - val_accuracy: 0.8266 - val_precision: 0.8536 - val_recall: 0.8019 - val_auc: 0.9692 - val_prc: 0.8816
# Epoch 64/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.5257 - accuracy: 0.8387 - precision: 0.8745 - recall: 0.8001 - auc: 0.9709 - prc: 0.8825 - val_loss: 0.5740 - val_accuracy: 0.8186 - val_precision: 0.8465 - val_recall: 0.7960 - val_auc: 0.9664 - val_prc: 0.8793
# Epoch 65/100
# 291/291 [==============================] - 40s 136ms/step - loss: 0.5299 - accuracy: 0.8388 - precision: 0.8751 - recall: 0.8020 - auc: 0.9702 - prc: 0.8791 - val_loss: 0.5549 - val_accuracy: 0.8242 - val_precision: 0.8509 - val_recall: 0.7980 - val_auc: 0.9671 - val_prc: 0.8781
# Epoch 66/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.5264 - accuracy: 0.8420 - precision: 0.8753 - recall: 0.8047 - auc: 0.9707 - prc: 0.8805 - val_loss: 0.5991 - val_accuracy: 0.8016 - val_precision: 0.8444 - val_recall: 0.7728 - val_auc: 0.9654 - val_prc: 0.8725
# Epoch 67/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.5156 - accuracy: 0.8378 - precision: 0.8752 - recall: 0.8038 - auc: 0.9719 - prc: 0.8836 - val_loss: 0.6042 - val_accuracy: 0.8068 - val_precision: 0.8379 - val_recall: 0.7818 - val_auc: 0.9647 - val_prc: 0.8747
# Epoch 68/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.5084 - accuracy: 0.8427 - precision: 0.8796 - recall: 0.8073 - auc: 0.9725 - prc: 0.8891 - val_loss: 0.5879 - val_accuracy: 0.8092 - val_precision: 0.8442 - val_recall: 0.7831 - val_auc: 0.9661 - val_prc: 0.8747
# Epoch 69/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.4945 - accuracy: 0.8489 - precision: 0.8805 - recall: 0.8169 - auc: 0.9738 - prc: 0.8943 - val_loss: 0.5314 - val_accuracy: 0.8253 - val_precision: 0.8533 - val_recall: 0.8012 - val_auc: 0.9687 - val_prc: 0.8855
# Epoch 70/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.5015 - accuracy: 0.8454 - precision: 0.8794 - recall: 0.8131 - auc: 0.9732 - prc: 0.8900 - val_loss: 0.5513 - val_accuracy: 0.8255 - val_precision: 0.8524 - val_recall: 0.8038 - val_auc: 0.9680 - val_prc: 0.8827
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 71/100
# 291/291 [==============================] - 40s 136ms/step - loss: 0.4772 - accuracy: 0.8527 - precision: 0.8832 - recall: 0.8201 - auc: 0.9753 - prc: 0.8971 - val_loss: 0.5276 - val_accuracy: 0.8294 - val_precision: 0.8604 - val_recall: 0.8126 - val_auc: 0.9697 - val_prc: 0.8900
# Epoch 72/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.4643 - accuracy: 0.8575 - precision: 0.8882 - recall: 0.8273 - auc: 0.9764 - prc: 0.9007 - val_loss: 0.5336 - val_accuracy: 0.8298 - val_precision: 0.8528 - val_recall: 0.8113 - val_auc: 0.9692 - val_prc: 0.8885
# Epoch 73/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.4608 - accuracy: 0.8580 - precision: 0.8866 - recall: 0.8283 - auc: 0.9768 - prc: 0.9027 - val_loss: 0.5069 - val_accuracy: 0.8373 - val_precision: 0.8613 - val_recall: 0.8160 - val_auc: 0.9715 - val_prc: 0.8913
# Epoch 74/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.4604 - accuracy: 0.8600 - precision: 0.8870 - recall: 0.8311 - auc: 0.9763 - prc: 0.8997 - val_loss: 0.5361 - val_accuracy: 0.8335 - val_precision: 0.8560 - val_recall: 0.8137 - val_auc: 0.9691 - val_prc: 0.8888
# Epoch 75/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.4516 - accuracy: 0.8609 - precision: 0.8886 - recall: 0.8321 - auc: 0.9775 - prc: 0.9023 - val_loss: 0.5502 - val_accuracy: 0.8305 - val_precision: 0.8493 - val_recall: 0.8113 - val_auc: 0.9688 - val_prc: 0.8870
# Epoch 76/100
# 291/291 [==============================] - 41s 139ms/step - loss: 0.4516 - accuracy: 0.8605 - precision: 0.8881 - recall: 0.8342 - auc: 0.9773 - prc: 0.9033 - val_loss: 0.5453 - val_accuracy: 0.8279 - val_precision: 0.8524 - val_recall: 0.8102 - val_auc: 0.9688 - val_prc: 0.8868
# Epoch 77/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.4495 - accuracy: 0.8620 - precision: 0.8896 - recall: 0.8347 - auc: 0.9775 - prc: 0.9057 - val_loss: 0.5343 - val_accuracy: 0.8290 - val_precision: 0.8560 - val_recall: 0.8111 - val_auc: 0.9696 - val_prc: 0.8919
# Epoch 78/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.4437 - accuracy: 0.8634 - precision: 0.8924 - recall: 0.8347 - auc: 0.9781 - prc: 0.9082 - val_loss: 0.5184 - val_accuracy: 0.8333 - val_precision: 0.8600 - val_recall: 0.8154 - val_auc: 0.9703 - val_prc: 0.8921
# Epoch 79/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.4381 - accuracy: 0.8651 - precision: 0.8923 - recall: 0.8376 - auc: 0.9784 - prc: 0.9092 - val_loss: 0.5403 - val_accuracy: 0.8330 - val_precision: 0.8578 - val_recall: 0.8148 - val_auc: 0.9679 - val_prc: 0.8907
# Epoch 80/100
# 291/291 [==============================] - 40s 139ms/step - loss: 0.4300 - accuracy: 0.8684 - precision: 0.8938 - recall: 0.8441 - auc: 0.9790 - prc: 0.9108 - val_loss: 0.5415 - val_accuracy: 0.8302 - val_precision: 0.8487 - val_recall: 0.8122 - val_auc: 0.9675 - val_prc: 0.8882
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 81/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.4217 - accuracy: 0.8716 - precision: 0.8977 - recall: 0.8450 - auc: 0.9798 - prc: 0.9126 - val_loss: 0.5162 - val_accuracy: 0.8376 - val_precision: 0.8604 - val_recall: 0.8193 - val_auc: 0.9698 - val_prc: 0.8934
# Epoch 82/100
# 291/291 [==============================] - 41s 140ms/step - loss: 0.4125 - accuracy: 0.8755 - precision: 0.8989 - recall: 0.8523 - auc: 0.9803 - prc: 0.9151 - val_loss: 0.5365 - val_accuracy: 0.8324 - val_precision: 0.8512 - val_recall: 0.8150 - val_auc: 0.9676 - val_prc: 0.8839
# Epoch 83/100
# 291/291 [==============================] - 41s 141ms/step - loss: 0.4096 - accuracy: 0.8740 - precision: 0.8982 - recall: 0.8514 - auc: 0.9810 - prc: 0.9189 - val_loss: 0.5241 - val_accuracy: 0.8384 - val_precision: 0.8599 - val_recall: 0.8216 - val_auc: 0.9696 - val_prc: 0.8906
# Epoch 84/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.4061 - accuracy: 0.8773 - precision: 0.9010 - recall: 0.8538 - auc: 0.9808 - prc: 0.9180 - val_loss: 0.5202 - val_accuracy: 0.8326 - val_precision: 0.8549 - val_recall: 0.8188 - val_auc: 0.9708 - val_prc: 0.8926
# Epoch 85/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.4039 - accuracy: 0.8765 - precision: 0.9016 - recall: 0.8541 - auc: 0.9810 - prc: 0.9176 - val_loss: 0.5512 - val_accuracy: 0.8315 - val_precision: 0.8503 - val_recall: 0.8126 - val_auc: 0.9665 - val_prc: 0.8846
# Epoch 86/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.4029 - accuracy: 0.8786 - precision: 0.9010 - recall: 0.8564 - auc: 0.9813 - prc: 0.9203 - val_loss: 0.5329 - val_accuracy: 0.8333 - val_precision: 0.8524 - val_recall: 0.8173 - val_auc: 0.9689 - val_prc: 0.8902
# Epoch 87/100
# 291/291 [==============================] - 40s 136ms/step - loss: 0.4168 - accuracy: 0.8735 - precision: 0.8978 - recall: 0.8519 - auc: 0.9799 - prc: 0.9147 - val_loss: 0.5285 - val_accuracy: 0.8313 - val_precision: 0.8548 - val_recall: 0.8158 - val_auc: 0.9694 - val_prc: 0.8887
# Epoch 88/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.3965 - accuracy: 0.8789 - precision: 0.9026 - recall: 0.8570 - auc: 0.9819 - prc: 0.9221 - val_loss: 0.5326 - val_accuracy: 0.8363 - val_precision: 0.8607 - val_recall: 0.8173 - val_auc: 0.9686 - val_prc: 0.8867
# Epoch 89/100
# 291/291 [==============================] - 41s 139ms/step - loss: 0.4016 - accuracy: 0.8799 - precision: 0.9037 - recall: 0.8585 - auc: 0.9814 - prc: 0.9212 - val_loss: 0.5357 - val_accuracy: 0.8320 - val_precision: 0.8546 - val_recall: 0.8141 - val_auc: 0.9684 - val_prc: 0.8845
# Epoch 90/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.3969 - accuracy: 0.8794 - precision: 0.9020 - recall: 0.8570 - auc: 0.9814 - prc: 0.9186 - val_loss: 0.5369 - val_accuracy: 0.8339 - val_precision: 0.8544 - val_recall: 0.8193 - val_auc: 0.9683 - val_prc: 0.8876
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 91/100
# 291/291 [==============================] - 39s 135ms/step - loss: 0.4010 - accuracy: 0.8786 - precision: 0.8996 - recall: 0.8587 - auc: 0.9812 - prc: 0.9175 - val_loss: 0.5274 - val_accuracy: 0.8356 - val_precision: 0.8568 - val_recall: 0.8214 - val_auc: 0.9684 - val_prc: 0.8910
# Epoch 92/100
# 291/291 [==============================] - 40s 138ms/step - loss: 0.3971 - accuracy: 0.8794 - precision: 0.9041 - recall: 0.8561 - auc: 0.9820 - prc: 0.9220 - val_loss: 0.5463 - val_accuracy: 0.8302 - val_precision: 0.8534 - val_recall: 0.8154 - val_auc: 0.9676 - val_prc: 0.8865
# Epoch 93/100
# 291/291 [==============================] - 40s 136ms/step - loss: 0.3953 - accuracy: 0.8773 - precision: 0.8998 - recall: 0.8567 - auc: 0.9815 - prc: 0.9221 - val_loss: 0.5228 - val_accuracy: 0.8313 - val_precision: 0.8557 - val_recall: 0.8163 - val_auc: 0.9701 - val_prc: 0.8919
# Epoch 94/100
# 291/291 [==============================] - 40s 137ms/step - loss: 0.3859 - accuracy: 0.8853 - precision: 0.9078 - recall: 0.8640 - auc: 0.9822 - prc: 0.9247 - val_loss: 0.5443 - val_accuracy: 0.8320 - val_precision: 0.8548 - val_recall: 0.8195 - val_auc: 0.9683 - val_prc: 0.8877
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping

# %% [markdown]
# # Statistics

# %%
Train_Val_Plot2(history1.history['accuracy'],history1.history['val_accuracy'],
               history1.history['loss'],history1.history['val_loss'],
               history1.history['auc'],history1.history['val_auc'],
               history1.history['precision'],history1.history['val_precision'],
               history1.history['recall'],history1.history['val_recall'],
               history1.history['prc'],history1.history['val_prc']
              )

# %%
model.save("emotion_model.h5")
print("Model saved as emotion_model.h5")
# Out:
# Model saved as emotion_model.h5
